# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_csv(
    "bupa.csv",
    header=None,
    names=["mcv","alkphos","sgpt","sgot","gammagt","drinks","selector"]
)

# Dichotomise target
df["target"] = (df["drinks"] >= 3).astype(int)

# Explanatory variables
X = df[["mcv","alkphos","sgpt","sgot","gammagt"]]

# Target
y = df["target"]

# Normalise explanatory variables
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

print(X_scaled.head())
print(y.value_counts())
# Out:
#         mcv   alkphos      sgpt      sgot   gammagt
# 0 -1.161601  1.207923  0.749035  0.234482 -0.185829
# 1 -1.161601 -0.320373  1.467573  0.732000 -0.389922
# 2 -0.936459 -0.866193  0.133145 -0.860056  0.400941
# 3  0.189250  0.443775  0.184469 -0.064028 -0.058270
# 4 -0.711318  0.007119 -0.944662  0.333986 -0.721575
# target
# 1    176
# 0    169
# Name: count, dtype: int64
